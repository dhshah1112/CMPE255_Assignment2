# %%
# !pip install pycaret

# %%
import pandas as pd
from pycaret.time_series import *

# %%
df = pd.read_csv('/content/drive/MyDrive/CMPE255/day.csv')

# %%
target_name = 'cnt'

# %%
df['dteday'] = pd.to_datetime(df['dteday'])

df.set_index('dteday', inplace=True)

# %%
s = setup(df, target = target_name,fold = 2, fh = 12,)
# Out:
# <style type="text/css">
# #T_d722b_row25_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_d722b" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d722b_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_d722b_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d722b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d722b_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_d722b_row0_col1" class="data row0 col1" >1057</td>
#     </tr>
#     <tr>
#       <th id="T_d722b_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_d722b_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_d722b_row1_col1" class="data row1 col1" >cnt</td>
#     </tr>
#     <tr>
#       <th id="T_d722b_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
check_stats()
# Out:
#             Test   Test Name         Data             Property  \
# 0        Summary  Statistics  Transformed               Length
# 1        Summary  Statistics  Transformed     # Missing Values
# 2        Summary  Statistics  Transformed                 Mean
# 3        Summary  Statistics  Transformed               Median
# 4        Summary  Statistics  Transformed   Standard Deviation
# 5        Summary  Statistics  Transformed             Variance
# 6        Summary  Statistics  Transformed             Kurtosis
# 7        Summary  Statistics  Transformed             Skewness
# 8        Summary  Statistics  Transformed    # Distinct Values
# 9    White Noise   Ljung-Box  Transformed       Test Statictic
# 10   White Noise   Ljung-Box  Transformed       Test Statictic
# 11   White Noise   Ljung-Box  Transformed              p-value
# 12   White Noise   Ljung-Box  Transformed              p-value
# 13   White Noise   Ljung-Box  Transformed          White Noise
# ...

# %%
best = compare_models()
# Out:
# <style type="text/css">
# #T_71a8f th {
#   text-align: left;
# }
# ...

# %%
aarima_model = create_model('auto_arima')
aarima_model_finalized = finalize_model(aarima_model)
# Out:
# <style type="text/css">
# #T_b78b0_row2_col0, #T_b78b0_row2_col1, #T_b78b0_row2_col2, #T_b78b0_row2_col3, #T_b78b0_row2_col4, #T_b78b0_row2_col5, #T_b78b0_row2_col6, #T_b78b0_row2_col7 {
#   background: yellow;
# }
# </style>
# <table id="T_b78b0" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b78b0_level0_col0" class="col_heading level0 col0" >cutoff</th>
#       <th id="T_b78b0_level0_col1" class="col_heading level0 col1" >MASE</th>
#       <th id="T_b78b0_level0_col2" class="col_heading level0 col2" >RMSSE</th>
#       <th id="T_b78b0_level0_col3" class="col_heading level0 col3" >MAE</th>
#       <th id="T_b78b0_level0_col4" class="col_heading level0 col4" >RMSE</th>
#       <th id="T_b78b0_level0_col5" class="col_heading level0 col5" >MAPE</th>
#       <th id="T_b78b0_level0_col6" class="col_heading level0 col6" >SMAPE</th>
#       <th id="T_b78b0_level0_col7" class="col_heading level0 col7" >R2</th>
#     </tr>
# ...

# %%
holdout_pred = predict_model(best)
# Out:
# <style type="text/css">
# </style>
# <table id="T_ae08b" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ae08b_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_ae08b_level0_col1" class="col_heading level0 col1" >MASE</th>
#       <th id="T_ae08b_level0_col2" class="col_heading level0 col2" >RMSSE</th>
#       <th id="T_ae08b_level0_col3" class="col_heading level0 col3" >MAE</th>
#       <th id="T_ae08b_level0_col4" class="col_heading level0 col4" >RMSE</th>
#       <th id="T_ae08b_level0_col5" class="col_heading level0 col5" >MAPE</th>
#       <th id="T_ae08b_level0_col6" class="col_heading level0 col6" >SMAPE</th>
#       <th id="T_ae08b_level0_col7" class="col_heading level0 col7" >R2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ae08b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ae08b_row0_col0" class="data row0 col0" >Auto ARIMA</td>
# ...

# %%
predict_model(best, fh = 12)
# Out:
# <style type="text/css">
# </style>
# <table id="T_081f4" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_081f4_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_081f4_level0_col1" class="col_heading level0 col1" >MASE</th>
#       <th id="T_081f4_level0_col2" class="col_heading level0 col2" >RMSSE</th>
#       <th id="T_081f4_level0_col3" class="col_heading level0 col3" >MAE</th>
#       <th id="T_081f4_level0_col4" class="col_heading level0 col4" >RMSE</th>
#       <th id="T_081f4_level0_col5" class="col_heading level0 col5" >MAPE</th>
#       <th id="T_081f4_level0_col6" class="col_heading level0 col6" >SMAPE</th>
#       <th id="T_081f4_level0_col7" class="col_heading level0 col7" >R2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_081f4_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_081f4_row0_col0" class="data row0 col0" >Auto ARIMA</td>
# ...
