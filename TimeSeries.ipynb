# %% [markdown]
# **WITHOUT exogenous**

# %%
# !pip install pycaret
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 484.4/484.4 kB 6.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 153.4/153.4 kB 20.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.8/81.8 kB 12.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 20.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.9/79.9 MB 12.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.8/106.8 kB 13.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.4/73.4 kB 9.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.5/17.5 MB 50.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.0/44.0 kB 5.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 62.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 59.7 MB/s eta 0:00:00
# ...

# %%
import tensorflow as tf
print("Num GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  0

# %%
import pandas as pd
df = pd.read_csv('/content/drive/MyDrive/CMPE255/Sunspots.csv')

# %%
print(df.columns)
# Out:
# Index(['Unnamed: 0', 'Date', 'Monthly Mean Total Sunspot Number'], dtype='object')

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %%
df.set_index('Date', inplace=True)

# %%
df.drop(df.columns[0], axis=1, inplace=True)

# %%
from pycaret.time_series import *
s = setup(df, target='Monthly Mean Total Sunspot Number', fold=3, fh=12, session_id=123)
# Out:
# <style type="text/css">
# #T_3d172_row25_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_3d172" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3d172_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_3d172_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3d172_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_3d172_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_3d172_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_3d172_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_3d172_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_3d172_row1_col1" class="data row1 col1" >Monthly Mean Total Sunspot Number</td>
#     </tr>
#     <tr>
# ...

# %%
arima = create_model('arima')
final_arima = finalize_model(arima)
# Out:
# <style type="text/css">
# #T_fd5fe_row3_col0, #T_fd5fe_row3_col1, #T_fd5fe_row3_col2, #T_fd5fe_row3_col3, #T_fd5fe_row3_col4, #T_fd5fe_row3_col5, #T_fd5fe_row3_col6, #T_fd5fe_row3_col7 {
#   background: yellow;
# }
# </style>
# <table id="T_fd5fe" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fd5fe_level0_col0" class="col_heading level0 col0" >cutoff</th>
#       <th id="T_fd5fe_level0_col1" class="col_heading level0 col1" >MASE</th>
#       <th id="T_fd5fe_level0_col2" class="col_heading level0 col2" >RMSSE</th>
#       <th id="T_fd5fe_level0_col3" class="col_heading level0 col3" >MAE</th>
#       <th id="T_fd5fe_level0_col4" class="col_heading level0 col4" >RMSE</th>
#       <th id="T_fd5fe_level0_col5" class="col_heading level0 col5" >MAPE</th>
#       <th id="T_fd5fe_level0_col6" class="col_heading level0 col6" >SMAPE</th>
#       <th id="T_fd5fe_level0_col7" class="col_heading level0 col7" >R2</th>
#     </tr>
# ...

# %%
future_predictions = predict_model(final_arima, verbose=True)
display(future_predictions)
# Out:
#           y_pred
# 2021-02  16.7666
# 2021-03   9.2883
# 2021-04  16.4833
# 2021-05   9.1800
# 2021-06  16.4119
# 2021-07   9.1165
# 2021-08  16.3501
# 2021-09   9.0549
# 2021-10  16.2886
# 2021-11   8.9935
# 2021-12  16.2271
# 2022-01   8.9320

# %% [markdown]
# ***WITH exogenous ***

# %%
new_df = pd.read_csv('/content/drive/MyDrive/CMPE255/day.csv')

# %%
import tensorflow as tf
print("Num GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  0

# %%
print(new_df.columns)
# Out:
# Index(['instant', 'dteday', 'season', 'yr', 'mnth', 'holiday', 'weekday',
#        'workingday', 'weathersit', 'temp', 'atemp', 'hum', 'windspeed',
#        'casual', 'registered', 'cnt'],
#       dtype='object')

# %%
new_df['dteday'] = pd.to_datetime(new_df['dteday'])
new_df.set_index('dteday', inplace=True)

# %%
print(new_df.isnull().sum())
# Out:
# instant       0
# season        0
# yr            0
# mnth          0
# holiday       0
# weekday       0
# workingday    0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %%
print(new_df.dtypes)
# Out:
# instant         int64
# season          int64
# yr              int64
# mnth            int64
# holiday         int64
# weekday         int64
# workingday      int64
# weathersit      int64
# temp          float64
# atemp         float64
# hum           float64
# windspeed     float64
# casual          int64
# registered      int64
# cnt             int64
# dtype: object

# %%
new_df.dropna(inplace=True)

# %%
# !pip install pycaret --upgrade

# %%
new_df.interpolate(method='linear', inplace=True)

# %%
from pycaret.time_series import *
setu = setup(new_df, target='cnt', fold=3, fh=12, session_id=214)
# Out:
# <style type="text/css">
# #T_277e4_row25_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_277e4" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_277e4_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_277e4_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_277e4_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_277e4_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_277e4_row0_col1" class="data row0 col1" >214</td>
#     </tr>
#     <tr>
#       <th id="T_277e4_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_277e4_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_277e4_row1_col1" class="data row1 col1" >cnt</td>
#     </tr>
#     <tr>
#       <th id="T_277e4_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
arima_exog = create_model('arima')
final_arima_exog = finalize_model(arima_exog)
# Out:
#
#
# Initiated  . . . . . . . . . . . . . . . . . .         20:15:54
# Status     . . . . . . . . . . . . . . . . . .  Fitting 3 Folds
# Estimator  . . . . . . . . . . . . . . . . . .            ARIMA
# Processing:   0%|          | 0/4 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# _RemoteTraceback                          Traceback (most recent call last)
# _RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/joblib/externals/loky/process_executor.py", line 463, in _process_worker
#     r = call_item()
#   File "/usr/local/lib/python3.10/dist-packages/joblib/externals/loky/process_executor.py", line 291, in __call__
#     return self.fn(*self.args, **self.kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/joblib/parallel.py", line 589, in __call__
#     return [func(*args, **kwargs)
# ...

# %%
future_predictions_exog = predict_model(final_arima_exog, verbose=True)
display(future_predictions_exog)
